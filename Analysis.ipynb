# %%
import pandas as pd

# %%
train= pd.read_csv("train.csv")
test1= pd.read_csv("test.csv")
test2= pd.read_csv("gender_submission.csv")
test = pd.merge(test1,test2)
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Cabin'].nunique()
# Out:
# 147

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## SEX

# %%
sns.countplot(data=train, x='Pclass', hue='Survived')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
dfs= train[train['Survived']==1]
dfd= train[train['Survived']==0]

# %% [markdown]
# ## CLASS

# %%
sns.countplot(data=dfs,x='Pclass',hue='Sex')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data=dfd,x='Pclass',hue='Sex')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ## FARE

# %%
train["FareF"] = train["Fare"]
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.hist(x=train['FareF'],bins=10)
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
train['FareF'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: FareF, dtype: float64

# %%
train['FareF'].mask(train['FareF']<=7.910400,4,inplace=True)
train['FareF'].mask(train['FareF'].between(7.910400,14.454201),3,inplace=True)
train['FareF'].mask(train['FareF'].between(14.454201,31.00000),2,inplace=True)
train['FareF'].mask(train['FareF']>=31.000000,1,inplace=True)

# %%
sns.countplot(data=train,x='FareF',hue='Survived')
# Out:
# <AxesSubplot: xlabel='FareF', ylabel='count'>

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Embarked

# %%
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
men = train[train["Sex"]=='male']
sns.countplot(data= men, x='Embarked',hue='Survived')
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='count'>

# %%
women = train[train["Sex"]=='female']
sns.countplot(data= women, x='Embarked',hue='Survived')
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='count'>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FareF
# 0      0         A/5 21171   7.2500   NaN        S    4.0
# 1      0          PC 17599  71.2833   C85        C    1.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    3.0
# 3      0            113803  53.1000  C123        S    1.0
# ...

# %% [markdown]
# ## AGE

# %%
women_and_children = train[(train['Sex'] == "female") | (train['Age'] < 16)]
women_and_children["Survived"].value_counts(normalize=True) * 100
# Out:
# 1    71.751412
# 0    28.248588
# Name: Survived, dtype: float64

# %%
adult_men = train[(train['Sex']=='male') & (train['Age'] > 16)]
adult_men['Survived'].value_counts(normalize=True) * 100
# Out:
# 0    82.338308
# 1    17.661692
# Name: Survived, dtype: float64

# %%
train['Title'] = train.Name.str.extract('([A-Za-z]+)\.')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
Mn= ['Mr','Don','Rev','Dr','Major','Sir','Col','Capt','Jonkheer']
Wn = ['Mrs','Mme','Lady','Countess']
boy= ['Master']
girl= ['Miss','Ms','Mlle']
train["Title"].replace(Mn,'Men',inplace=True)
train["Title"].replace(Wn,'Women',inplace=True)
train["Title"].replace(boy,'Boy',inplace=True)
train["Title"].replace(girl,'Girl',inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train["Title"].unique()
# Out:
# array(['Men', 'Women', 'Girl', 'Boy'], dtype=object)

# %%
medianmen= np.median(train[train["Title"]=='Men']['Age'].dropna())
train.loc[(train['Title']=='Men') & (train['Age'].isna()),'Age']  = medianmen

medianwomen= np.median(train[train["Title"]=='Women']['Age'].dropna())
train.loc[(train['Title']=='Women') & (train['Age'].isna()),'Age']  = medianwomen

medianboy= np.median(train[train["Title"]=='Boy']['Age'].dropna())
train.loc[(train['Title']=='Boy') & (train['Age'].isna()),'Age']  = medianboy

mediangirl= np.median(train[train["Title"]=='Girl']['Age'].dropna())
train.loc[(train['Title']=='Girl') & (train['Age'].isna()),'Age']  = mediangirl

# %%
men = train[train["Sex"]=='male']
women = train[train["Sex"]=='female']

# %%
sns.distplot(women[women['Survived']==0].Age, bins=20, color='r')
sns.distplot(women[women['Survived']==1].Age, bins=20, color='g')
print(women[women['Survived']==1].Age.mean())
print(women[women['Survived']==0].Age.mean())
# Out:
# 28.476394849785407
# 24.71604938271605
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\4101920054.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(women[women['Survived']==0].Age, bins=20, color='r')
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\4101920054.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(16, 8))

ax=sns.distplot(men[men['Survived']==0].Age, bins=20, color='r')
ax=sns.distplot(men[men['Survived']==1].Age, bins=20, color='g')
print(men[men['Survived']==1].Age.mean())
print(men[men['Survived']==0].Age.mean())
# Out:
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\2135332261.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(men[men['Survived']==0].Age, bins=20, color='r')
# 27.189633027522937
# 31.131410256410255
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\2135332261.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## Family Size

# %%
train["Family"]= train['SibSp']+train['Parch']
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(train, x='Family', hue="Survived")
# Out:
# <AxesSubplot: xlabel='Family', ylabel='count'>

# %% [markdown]
# ## Modelling

# %%
train.dropna(subset=["Embarked"],inplace=True)
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FareF            0
# Title            0
# Family           0
# dtype: int64

# %%
x_train = train[["Sex","Age","Pclass","SibSp","Parch","Embarked","Fare"]]
x_train
# Out:
#         Sex   Age  Pclass  SibSp  Parch Embarked     Fare
# 0      male  22.0       3      1      0        S   7.2500
# 1    female  38.0       1      1      0        C  71.2833
# 2    female  26.0       3      0      0        S   7.9250
# 3    female  35.0       1      1      0        S  53.1000
# 4      male  35.0       3      0      0        S   8.0500
# ..      ...   ...     ...    ...    ...      ...      ...
# 886    male  27.0       2      0      0        S  13.0000
# 887  female  19.0       1      0      0        S  30.0000
# 888  female  21.0       3      1      2        S  23.4500
# 889    male  26.0       1      0      0        C  30.0000
# 890    male  32.0       3      0      0        Q   7.7500
#
# [889 rows x 7 columns]

# %%
y_train = train[["Survived"]]
y_train
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [889 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

x_train['Sex']=le.fit_transform(x_train['Sex'])
x_train['Embarked']=le.fit_transform(x_train['Embarked'])
x_train
# Out:
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\228660505.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['Sex']=le.fit_transform(x_train['Sex'])
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\228660505.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['Embarked']=le.fit_transform(x_train['Embarked'])
#      Sex   Age  Pclass  SibSp  Parch  Embarked     Fare
# 0      1  22.0       3      1      0         2   7.2500
# ...

# %%
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
test['Title'] = test.Name.str.extract('([A-Za-z]+)\.')
test["Title"].replace(Mn,'Men',inplace=True)
test["Title"].replace(Wn,'Women',inplace=True)
test["Title"].replace(boy,'Boy',inplace=True)
test["Title"].replace(girl,'Girl',inplace=True)

medianmen= np.median(test[test["Title"]=='Men']['Age'].dropna())
test.loc[(test['Title']=='Men') & (test['Age'].isna()),'Age']  = medianmen

medianwomen= np.median(test[test["Title"]=='Women']['Age'].dropna())
test.loc[(test['Title']=='Women') & (test['Age'].isna()),'Age']  = medianwomen

medianboy= np.median(test[test["Title"]=='Boy']['Age'].dropna())
test.loc[(test['Title']=='Boy') & (test['Age'].isna()),'Age']  = medianboy

mediangirl= np.median(test[test["Title"]=='Girl']['Age'].dropna())
test.loc[(test['Title']=='Girl') & (test['Age'].isna()),'Age']  = mediangirl
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %%
#test.dropna(subset=["Fare"],inplace=True)
#test.isnull().sum()

# %%
x_test=test[["Sex","Age","Pclass","SibSp","Parch","Embarked","Fare"]]
y_test=test[["Survived"]]
x_test['Sex']=le.fit_transform(x_test['Sex'])
x_test['Embarked']=le.fit_transform(x_test['Embarked'])
x_test.describe()
# Out:
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\671648372.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Sex']=le.fit_transform(x_test['Sex'])
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\671648372.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Embarked']=le.fit_transform(x_test['Embarked'])
#               Sex         Age      Pclass       SibSp       Parch    Embarked  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# ...

# %%
x_test[x_test.isnull().any(axis=1)]
x_test["Fare"].fillna(7.895800,inplace=True)
x_test.isna().sum()
# Out:
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\2941450028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test["Fare"].fillna(7.895800,inplace=True)
# Sex         0
# Age         0
# Pclass      0
# SibSp       0
# Parch       0
# Embarked    0
# Fare        0
# dtype: int64

# %% [markdown]
# ## DECISON TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#classifier= DecisionTreeClassifier(criterion='entropy', random_state=0,max_depth=5)  

parameters = {'max_depth':range(3,30)}
classifier = GridSearchCV(DecisionTreeClassifier(), parameters, n_jobs=4)
classifier.fit(X=x_train, y=y_train)
tree_model = classifier.best_estimator_
print (classifier.best_score_, classifier.best_params_)
# Out:
# 0.8122008506316257 {'max_depth': 5}

# %%
#classifier.fit(x_train, y_train)
y_pred= tree_model.predict(x_test)

# %%
from sklearn import metrics
cm= metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [0, 1])

cm_display.plot()
plt.show()
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.937799043062201

# %%
pred = pd.DataFrame(y_pred)
pred.to_csv("DecisionTreeFare.csv")

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
#LR = LogisticRegression(solver='liblinear')
parameters = {"C":[0.001, 0.01, 0.1, 1, 10, 100], "penalty":["l1","l2"], "solver":['newton-cg', 'lbfgs', 'liblinear', 'sag']}
LR = GridSearchCV(LogisticRegression(), parameters, n_jobs=4)
LR.fit(X=x_train, y=y_train)

print("tuned hpyerparameters :(best parameters) ",LR.best_params_)
print("accuracy :",LR.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# accuracy : 0.7964451215641464
# D:\Data Science Projects\python installer\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 90 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Data Science Projects\python installer\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Data Science Projects\python installer\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
# ...

# %%
#LR = LogisticRegression(C=0.1,solver='liblinear').fit(x_train,y_train)
y_pred= LR.predict(x_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9138755980861244

# %%
from sklearn import metrics
lr= metrics.confusion_matrix(y_test, y_pred)
lr_display = metrics.ConfusionMatrixDisplay(confusion_matrix = lr, display_labels = [0, 1])

lr_display.plot()
plt.show()
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9138755980861244

# %%
pred = pd.DataFrame(y_pred)
pred.to_csv("NewtonFare.csv")

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier  
RF= RandomForestClassifier(criterion='gini', 
                             n_estimators=100,
                             min_samples_split=3,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=4)  
RF.fit(x_train, y_train)
y_pred= RF.predict(x_test)
# Out:
# C:\Users\joyal\AppData\Local\Temp\ipykernel_21096\2647141746.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF.fit(x_train, y_train)
# D:\Data Science Projects\python installer\Lib\site-packages\sklearn\ensemble\_forest.py:425: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
from sklearn import metrics
rf= metrics.confusion_matrix(y_test, y_pred)
rf_display = metrics.ConfusionMatrixDisplay(confusion_matrix = rf, display_labels = [0, 1])

rf_display.plot()
plt.show()
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8110047846889952

# %%
pred = pd.DataFrame(y_pred)
pred.to_csv("RandomForestFare.csv")
